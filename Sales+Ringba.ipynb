# %%
import requests
import json
import pandas as pd
import datetime, time
from io import BytesIO
import zipfile
import os
import mysql.connector
from sqlalchemy import create_engine
import glob

# %%
today = datetime.date.today()

# Calculate yesterday
yesterday = today - datetime.timedelta(days=1)

# If today is Monday (weekday() function returns 0 for Monday) then set yesterday to be last Friday
if today.weekday() == 0:
    yesterday = today - datetime.timedelta(days=3)

# Convert yeserday variable to string
yesterday = str(yesterday)

# This section is not required anymore as you're not using 'day' and 'today' variables anywhere
# day = datetime.date.today()
# today = time.strftime("%Y-%m-%d")

# Calculate start and end time for the given day
start = yesterday + 'T' + '00:00:00Z'
end = yesterday + 'T' + '23:59:59Z'

# %%
import requests

cookies = {
    'PROJECTXSESS': 'qgaeh1tq66ird38qrvcjoivfg0',
    'last_seen': '1679431570292',
    '__zlcmid': '1EzlgjSKwrLRww0',
    'fs_uid': '#8G8WF#5983296036917248:5296222572892160:::#0374175d#/1710967568',
    'UBUNTUSERVERADMINCOOKIE': 'admin112',
}

headers = {
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json;charset=UTF-8',
    # 'Cookie': 'PROJECTXSESS=qgaeh1tq66ird38qrvcjoivfg0; last_seen=1679431570292; __zlcmid=1EzlgjSKwrLRww0; fs_uid=#8G8WF#5983296036917248:5296222572892160:::#0374175d#/1710967568; UBUNTUSERVERADMINCOOKIE=admin112',
    'Origin': 'https://admin-dt.convoso.com',
    'Referer': 'https://admin-dt.convoso.com/call-logs',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 Edg/114.0.0.0',
    'sec-ch-ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Microsoft Edge";v="114"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

json_data = {
    'export': 'no',
    'type': 'main',
    'selectOptions': [
        {
            'name': 'status',
            'operator': 'IN',
            'value': [
                'SALE',
                'SSALE',
            ],
            'type': '2',
        },
    ],
    'orderOptions': {
        'name': 'id',
        'value': 'DESC',
    },
    'page': 0,
    'limit': 20000,
    'start_date': start,
    'end_date': end,
    'columns_list': {
        'id': {
            'value': 'id',
            'dynamic_show': 'none',
            'name': 'Call Log ID',
            'type_show': 'number',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 2,
            'temp_show': True,
        },
        'lead_id': {
            'value': 'lead_id',
            'dynamic_show': 'lead_id',
            'name': 'Lead ID',
            'type_show': 'number',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 1,
            'temp_show': True,
        },
        'log_phone_number': {
            'value': 'log_phone_number',
            'dynamic_show': 'none',
            'name': 'Number Dialed',
            'type_show': 'number',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 7,
            'temp_show': True,
        },
        'caller_id_displayed': {
            'value': 'caller_id_displayed',
            'dynamic_show': 'caller_id_displayed',
            'name': 'Caller ID',
            'type_show': 'number',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 9,
            'temp_show': True,
        },
        'status_name': {
            'value': 'status_name',
            'dynamic_show': 'none',
            'name': 'Status Name',
            'type_show': 'string',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 56,
            'temp_show': True,
        },
        'call_date': {
            'value': 'call_date',
            'dynamic_show': 'call_date',
            'name': 'Time Stamp (PST)',
            'type_show': 'string',
            'show': True,
            'section': 'Time',
            'table': 'log',
            'order': 10,
            'temp_show': True,
        },
        'user_name': {
            'value': 'user_name',
            'dynamic_show': 'user_name',
            'name': 'Agent Name',
            'type_show': 'string',
            'show': True,
            'section': 'Agent',
            'table': 'log',
            'order': 11,
            'temp_show': True,
        },
        'length_in_sec': {
            'value': 'length_in_sec',
            'dynamic_show': 'none',
            'name': 'Talk Time',
            'type_show': 'number',
            'show': True,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 12,
            'temp_show': True,
        },
        'bill_time': {
            'value': 'bill_time',
            'dynamic_show': 'none',
            'name': 'Bill Time',
            'type_show': 'string',
            'show': True,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 13,
            'temp_show': True,
        },
        'queue_seconds': {
            'value': 'queue_seconds',
            'dynamic_show': 'none',
            'name': 'Queue Wait Time',
            'type_show': 'string',
            'show': False,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 14,
            'temp_show': False,
        },
        'cost': {
            'value': 'cost',
            'dynamic_show': 'decimal_5',
            'name': 'Cost',
            'type_show': 'number',
            'show': False,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 15,
            'temp_show': False,
        },
        'call_type': {
            'value': 'call_type',
            'dynamic_show': 'call_type',
            'name': 'Call Type',
            'type_show': 'string',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 16,
            'temp_show': True,
        },
        'term_reason': {
            'value': 'term_reason',
            'dynamic_show': 'term_reason',
            'name': 'Termination Reason',
            'type_show': 'string',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 17,
            'temp_show': True,
        },
        'out_called_count': {
            'value': 'out_called_count',
            'dynamic_show': 'none',
            'name': 'Outbound Called Count',
            'type_show': 'number',
            'show': True,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 18,
            'temp_show': True,
        },
        'campaign_name': {
            'value': 'campaign_name',
            'dynamic_show': 'campaign_name',
            'name': 'Campaign Name',
            'type_show': 'string',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 3,
            'temp_show': True,
        },
        'directory_name': {
            'value': 'directory_name',
            'dynamic_show': 'directory_name',
            'name': 'List Name',
            'type_show': 'string',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 19,
            'temp_show': False,
        },
        'queue_name': {
            'value': 'queue_name',
            'dynamic_show': 'none',
            'name': 'Queue Name',
            'type_show': 'string',
            'show': True,
            'section': 'Calls',
            'table': 'log',
            'order': 20,
            'temp_show': True,
        },
        'recording': {
            'value': 'recording',
            'dynamic_show': 'recording',
            'name': 'Recordings',
            'type_show': 'string',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 21,
            'temp_show': False,
        },
        'agent_comment': {
            'value': 'agent_comment',
            'dynamic_show': 'none',
            'name': 'Comment',
            'type_show': 'string',
            'show': True,
            'section': 'Agent',
            'table': 'log',
            'order': 22,
            'temp_show': True,
        },
        'audio_score': {
            'value': 'audio_score',
            'dynamic_show': 'audio_score',
            'name': 'Audio Quality',
            'type_show': 'string',
            'show': False,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 23,
            'temp_show': False,
        },
        'revenue': {
            'value': 'revenue',
            'dynamic_show': 'none',
            'name': 'Revenue',
            'type_show': 'number',
            'show': False,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 30,
            'temp_show': False,
        },
        'returns': {
            'value': 'returns',
            'dynamic_show': 'none',
            'name': 'Returned',
            'type_show': 'string',
            'show': False,
            'section': 'Call Statistics',
            'table': 'log',
            'order': 31,
            'temp_show': False,
        },
        'agent_email': {
            'value': 'agent_email',
            'dynamic_show': 'none',
            'name': 'Agent Email',
            'type_show': 'string',
            'show': False,
            'section': 'Agent',
            'table': 'user',
            'order': 24,
            'temp_show': False,
        },
        'extension': {
            'value': 'extension',
            'dynamic_show': 'none',
            'name': 'Agent Extension',
            'type_show': 'number',
            'show': False,
            'section': 'Agent',
            'table': 'phone',
            'order': 25,
            'temp_show': False,
        },
        'agent_first_name': {
            'value': 'agent_first_name',
            'dynamic_show': 'none',
            'name': 'Agent First Name',
            'type_show': 'string',
            'show': False,
            'section': 'Agent',
            'table': 'user',
            'order': 27,
            'temp_show': False,
        },
        'user_id': {
            'value': 'user_id',
            'dynamic_show': 'none',
            'name': 'Agent ID',
            'type_show': 'number',
            'show': False,
            'section': 'Agent',
            'table': 'log',
            'order': 29,
            'temp_show': False,
        },
        'agent_last_name': {
            'value': 'agent_last_name',
            'dynamic_show': 'none',
            'name': 'Agent Last Name',
            'type_show': 'string',
            'show': False,
            'section': 'Agent',
            'table': 'user',
            'order': 33,
            'temp_show': False,
        },
        'called_since_last_reset': {
            'value': 'called_since_last_reset',
            'dynamic_show': 'none',
            'name': 'Called Since Last Reset',
            'type_show': 'string',
            'show': False,
            'section': 'Call Statistics',
            'table': 'lead',
            'order': 36,
            'temp_show': False,
        },
        'dispo_sec': {
            'value': 'dispo_sec',
            'dynamic_show': 'none',
            'name': 'Wrap-up Time',
            'type_show': 'number',
            'show': False,
            'section': 'Call Statistics',
            'table': 'agent_log',
            'order': 37,
            'temp_show': False,
        },
        'date_and_hour': {
            'value': 'date_and_hour',
            'dynamic_show': 'none',
            'name': 'Date and Hour',
            'type_show': 'string',
            'show': True,
            'section': 'Time',
            'table': 'log',
            'order': 38,
            'temp_show': True,
        },
        'day_of_month': {
            'value': 'day_of_month',
            'dynamic_show': 'none',
            'name': 'Day of Month',
            'type_show': 'number',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 39,
            'temp_show': False,
        },
        'day_of_week': {
            'value': 'day_of_week',
            'dynamic_show': 'none',
            'name': 'Day of Week',
            'type_show': 'string',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 40,
            'temp_show': False,
        },
        'end_epoch': {
            'value': 'end_epoch',
            'dynamic_show': 'none',
            'name': 'End Epoch',
            'type_show': 'number',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 41,
            'temp_show': False,
        },
        'hour': {
            'value': 'hour',
            'dynamic_show': 'none',
            'name': 'Hour',
            'type_show': 'number',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 42,
            'temp_show': False,
        },
        'month': {
            'value': 'month',
            'dynamic_show': 'none',
            'name': 'Month',
            'type_show': 'string',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 43,
            'temp_show': False,
        },
        'start_epoch': {
            'value': 'start_epoch',
            'dynamic_show': 'none',
            'name': 'Start Epoch',
            'type_show': 'number',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 44,
            'temp_show': False,
        },
        'call_log_time': {
            'value': 'call_log_time',
            'dynamic_show': 'none',
            'name': 'Time',
            'type_show': 'number',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 45,
            'temp_show': False,
        },
        'year': {
            'value': 'year',
            'dynamic_show': 'none',
            'name': 'Year',
            'type_show': 'number',
            'show': False,
            'section': 'Time',
            'table': 'log',
            'order': 46,
            'temp_show': False,
        },
        'alt_dial': {
            'value': 'alt_dial',
            'dynamic_show': 'none',
            'name': 'Alternate Number to Dial',
            'type_show': 'number',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 47,
            'temp_show': False,
        },
        'campaign_id': {
            'value': 'campaign_id',
            'dynamic_show': 'none',
            'name': 'Campaign ID',
            'type_show': 'number',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 48,
            'temp_show': False,
        },
        'campaign_type': {
            'value': 'campaign_type',
            'dynamic_show': 'none',
            'name': 'Campaign Type',
            'type_show': 'string',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 49,
            'temp_show': False,
        },
        'queue_id': {
            'value': 'queue_id',
            'dynamic_show': 'queue_id',
            'name': 'Queue ID',
            'type_show': 'number',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 52,
            'temp_show': False,
        },
        'call_id': {
            'value': 'call_id',
            'dynamic_show': 'none',
            'name': 'Session ID',
            'type_show': 'number',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 53,
            'temp_show': False,
        },
        'status': {
            'value': 'status',
            'dynamic_show': 'status',
            'name': 'Status',
            'type_show': 'string',
            'show': False,
            'section': 'Calls',
            'table': 'log',
            'order': 54,
            'temp_show': False,
        },
        'originating_agent_id': {
            'value': 'originating_agent_id',
            'dynamic_show': 'none',
            'name': 'Originating Agent ID',
            'type_show': 'number',
            'show': False,
            'section': 'Agent',
            'table': 'log',
            'order': 50,
            'temp_show': False,
        },
        'originating_agent_name': {
            'value': 'originating_agent_name',
            'dynamic_show': 'originating_agent_name',
            'name': 'Originating Agent Name',
            'type_show': 'string',
            'show': True,
            'section': 'Agent',
            'table': 'log',
            'order': 51,
            'temp_show': True,
        },
        'owner_id': {
            'value': 'owner_id',
            'dynamic_show': 'owner_id',
            'name': 'Lead Owner',
            'show': False,
            'temp_show': False,
            'section': 'Agent',
            'order': 81,
        },
        'last_modified_by': {
            'value': 'last_modified_by',
            'dynamic_show': 'last_modified_by',
            'name': 'Last Modified By',
            'show': False,
            'temp_show': False,
            'section': 'Agent',
            'order': 80,
        },
        'created_by': {
            'value': 'created_by',
            'dynamic_show': 'created_by',
            'name': 'Created By',
            'show': False,
            'temp_show': False,
            'section': 'Agent',
            'order': 55,
        },
        'address1': {
            'value': 'address1',
            'dynamic_show': 'none',
            'name': 'Address 1',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 28,
            'temp_show': False,
        },
        'address2': {
            'value': 'address2',
            'dynamic_show': 'none',
            'name': 'Address 2',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 62,
            'temp_show': False,
        },
        'field_217': {
            'value': 'field_217',
            'dynamic_show': 'none',
            'name': 'AgentX (UHC Only)',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 59,
            'temp_show': False,
        },
        'field_41': {
            'value': 'field_41',
            'dynamic_show': 'none',
            'name': 'Annual Premium ($)',
            'show': False,
            'type_show': 'integer',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 60,
            'temp_show': False,
        },
        'field_210': {
            'value': 'field_210',
            'dynamic_show': 'none',
            'name': 'blueink_token',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 61,
            'temp_show': False,
        },
        'carrier_name': {
            'value': 'carrier_name',
            'dynamic_show': 'none',
            'name': 'Carrier Name',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 63,
            'temp_show': False,
        },
        'carrier_type': {
            'value': 'carrier_type',
            'dynamic_show': 'none',
            'name': 'Carrier Type',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 64,
            'temp_show': False,
        },
        'alt_phone_1': {
            'value': 'alt_phone_1',
            'dynamic_show': 'none',
            'name': 'Cell Phone',
            'show': False,
            'type_show': 'phone',
            'section': 'Contact',
            'table': 'lead',
            'order': 65,
            'temp_show': False,
        },
        'city': {
            'value': 'city',
            'dynamic_show': 'none',
            'name': 'City',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 32,
            'temp_show': False,
        },
        'field_95': {
            'value': 'field_95',
            'dynamic_show': 'decimal_2',
            'name': 'Cost',
            'show': False,
            'type_show': 'number',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 67,
            'temp_show': False,
        },
        'country': {
            'value': 'country',
            'dynamic_show': 'none',
            'name': 'Country',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 68,
            'temp_show': False,
        },
        'phone_code': {
            'value': 'phone_code',
            'dynamic_show': 'none',
            'name': 'Country Code',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead',
            'order': 69,
            'temp_show': False,
        },
        'created_at': {
            'value': 'created_at',
            'dynamic_show': 'none',
            'name': 'Created At (Time)',
            'show': True,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 57,
            'temp_show': True,
        },
        'date_of_birth': {
            'value': 'date_of_birth',
            'dynamic_show': 'none',
            'name': 'Date Of Birth',
            'show': False,
            'type_show': 'date',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 70,
            'temp_show': False,
        },
        'field_214': {
            'value': 'field_214',
            'dynamic_show': 'none',
            'name': 'DialedNumber Name',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 72,
            'temp_show': False,
        },
        'email': {
            'value': 'email',
            'dynamic_show': 'none',
            'name': 'Email',
            'show': False,
            'type_show': 'email',
            'section': 'Contact',
            'table': 'lead',
            'order': 8,
            'temp_show': False,
        },
        'final_reached_at': {
            'value': 'final_reached_at',
            'dynamic_show': 'none',
            'name': 'Final Reached At',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 71,
            'temp_show': False,
        },
        'first_name': {
            'value': 'first_name',
            'dynamic_show': 'none',
            'name': 'First Name',
            'show': True,
            'section': 'Contact',
            'table': 'lead',
            'order': 4,
            'temp_show': True,
        },
        'field_43': {
            'value': 'field_43',
            'dynamic_show': 'none',
            'name': 'FL Call Counter',
            'show': False,
            'type_show': 'integer',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 73,
            'temp_show': False,
        },
        'gender': {
            'value': 'gender',
            'dynamic_show': 'none',
            'name': 'Gender',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 74,
            'temp_show': False,
        },
        'gmt_offset_now': {
            'value': 'gmt_offset_now',
            'dynamic_show': 'decimal_2',
            'name': 'GMT Offset Now',
            'show': False,
            'section': 'Contact',
            'type_show': 'number',
            'table': 'lead',
            'order': 26,
            'temp_show': False,
        },
        'field_216': {
            'value': 'field_216',
            'dynamic_show': 'none',
            'name': 'HRA',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 76,
            'temp_show': False,
        },
        'field_206': {
            'value': 'field_206',
            'dynamic_show': 'none',
            'name': 'Jornaya Hidden Field',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 75,
            'temp_show': False,
        },
        'last_local_call_time': {
            'value': 'last_local_call_time',
            'dynamic_show': 'none',
            'name': 'Last Called (PST)',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 77,
            'temp_show': False,
        },
        'last_name': {
            'value': 'last_name',
            'dynamic_show': 'none',
            'name': 'Last Name',
            'show': True,
            'section': 'Contact',
            'table': 'lead',
            'order': 5,
            'temp_show': True,
        },
        'last_reached_at': {
            'value': 'last_reached_at',
            'dynamic_show': 'none',
            'name': 'Last Reached At',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 78,
            'temp_show': False,
        },
        'last_viewed_date': {
            'value': 'last_viewed_date',
            'dynamic_show': 'none',
            'name': 'Last Viewed',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 79,
            'temp_show': False,
        },
        'field_12': {
            'value': 'field_12',
            'dynamic_show': 'none',
            'name': 'LeadsPedia Affiliate ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 83,
            'temp_show': False,
        },
        'field_13': {
            'value': 'field_13',
            'dynamic_show': 'none',
            'name': 'LeadsPedia Campaign ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 84,
            'temp_show': False,
        },
        'field_11': {
            'value': 'field_11',
            'dynamic_show': 'none',
            'name': 'LeadsPedia Lead ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 85,
            'temp_show': False,
        },
        'field_14': {
            'value': 'field_14',
            'dynamic_show': 'none',
            'name': 'LeadsPedia Offer ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 87,
            'temp_show': False,
        },
        'field_15': {
            'value': 'field_15',
            'dynamic_show': 'none',
            'name': 'LeadsPedia Vertical ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 88,
            'temp_show': False,
        },
        'field_2': {
            'value': 'field_2',
            'dynamic_show': 'none',
            'name': 'Life Product',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 92,
            'temp_show': False,
        },
        'field_215': {
            'value': 'field_215',
            'dynamic_show': 'none',
            'name': 'Life Product Application ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 86,
            'temp_show': False,
        },
        'list_id': {
            'value': 'list_id',
            'dynamic_show': 'none',
            'name': 'List',
            'show': True,
            'type_show': 'lookup',
            'section': 'Contact',
            'table': 'lead',
            'order': 89,
            'temp_show': True,
        },
        'field_209': {
            'value': 'field_209',
            'dynamic_show': 'none',
            'name': 'lp_campaign_key',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 90,
            'temp_show': False,
        },
        'field_218': {
            'value': 'field_218',
            'dynamic_show': 'none',
            'name': 'Medicaid Number',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 82,
            'temp_show': False,
        },
        'field_4': {
            'value': 'field_4',
            'dynamic_show': 'none',
            'name': 'Medicare Number',
            'show': True,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 91,
            'temp_show': True,
        },
        'field_81': {
            'value': 'field_81',
            'dynamic_show': 'none',
            'name': 'Medicare Part A Date',
            'show': False,
            'type_show': 'date',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 93,
            'temp_show': False,
        },
        'field_82': {
            'value': 'field_82',
            'dynamic_show': 'none',
            'name': 'Medicare Part B Date',
            'show': False,
            'type_show': 'date',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 94,
            'temp_show': False,
        },
        'modified_at': {
            'value': 'modified_at',
            'dynamic_show': 'none',
            'name': 'Last Modify',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 58,
            'temp_show': False,
        },
        'field_101': {
            'value': 'field_101',
            'dynamic_show': 'none',
            'name': 'Notes',
            'show': False,
            'type_show': 'textarea_long',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 95,
            'temp_show': False,
        },
        'field_20': {
            'value': 'field_20',
            'dynamic_show': 'none',
            'name': 'Plan',
            'show': True,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 96,
            'temp_show': True,
        },
        'postal_code': {
            'value': 'postal_code',
            'dynamic_show': 'none',
            'name': 'Postal Code',
            'show': True,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead',
            'order': 35,
            'temp_show': True,
        },
        'field_93': {
            'value': 'field_93',
            'dynamic_show': 'decimal_2',
            'name': 'Premium',
            'show': True,
            'type_show': 'number',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 66,
            'temp_show': True,
        },
        'phone_number': {
            'value': 'phone_number',
            'dynamic_show': 'none',
            'name': 'Primary Phone',
            'show': True,
            'type_show': 'phone',
            'section': 'Contact',
            'table': 'lead',
            'order': 6,
            'temp_show': True,
        },
        'field_17': {
            'value': 'field_17',
            'dynamic_show': 'none',
            'name': 'Product',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 97,
            'temp_show': False,
        },
        'field_3': {
            'value': 'field_3',
            'dynamic_show': 'none',
            'name': 'Product Application ID',
            'show': True,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 114,
            'temp_show': True,
        },
        'field_19': {
            'value': 'field_19',
            'dynamic_show': 'none',
            'name': 'Product Application ID (OLD)',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 98,
            'temp_show': False,
        },
        'field_18': {
            'value': 'field_18',
            'dynamic_show': 'none',
            'name': 'Product Carrier',
            'show': True,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 100,
            'temp_show': True,
        },
        'province': {
            'value': 'province',
            'dynamic_show': 'none',
            'name': 'Province',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 102,
            'temp_show': False,
        },
        'field_301': {
            'value': 'field_301',
            'dynamic_show': 'none',
            'name': 'ringba_conversion',
            'show': False,
            'type_show': 'integer',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 101,
            'temp_show': False,
        },
        'field_212': {
            'value': 'field_212',
            'dynamic_show': 'none',
            'name': 'Ringba Call ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 108,
            'temp_show': False,
        },
        'field_83': {
            'value': 'field_83',
            'dynamic_show': 'none',
            'name': 'Sale Date',
            'show': False,
            'type_show': 'datetime',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 103,
            'temp_show': False,
        },
        'field_16': {
            'value': 'field_16',
            'dynamic_show': 'none',
            'name': 'Sale Status',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 104,
            'temp_show': False,
        },
        'security_phrase': {
            'value': 'security_phrase',
            'dynamic_show': 'none',
            'name': 'Security Phrase',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 105,
            'temp_show': False,
        },
        'source_id': {
            'value': 'source_id',
            'dynamic_show': 'none',
            'name': 'Source Id',
            'show': False,
            'section': 'Contact',
            'type_show': 'number',
            'table': 'lead',
            'order': 106,
            'temp_show': False,
        },
        'source_name': {
            'value': 'source_name',
            'dynamic_show': 'none',
            'name': 'Source Name',
            'show': True,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 107,
            'temp_show': True,
        },
        'field_7': {
            'value': 'field_7',
            'dynamic_show': 'none',
            'name': 'Source Lead List',
            'show': True,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 109,
            'temp_show': True,
        },
        'field_30': {
            'value': 'field_30',
            'dynamic_show': 'none',
            'name': "Spouse's Address",
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 110,
            'temp_show': False,
        },
        'field_31': {
            'value': 'field_31',
            'dynamic_show': 'none',
            'name': "Spouse's City",
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 111,
            'temp_show': False,
        },
        'field_401': {
            'value': 'field_401',
            'dynamic_show': 'none',
            'name': "Spouse's Date of Birth",
            'show': False,
            'type_show': 'date',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 113,
            'temp_show': False,
        },
        'field_42': {
            'value': 'field_42',
            'dynamic_show': 'none',
            'name': "Spouse's  Life Premium",
            'show': False,
            'type_show': 'integer',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 119,
            'temp_show': False,
        },
        'field_84': {
            'value': 'field_84',
            'dynamic_show': 'none',
            'name': "Spouse's Medicare Part A Plan",
            'show': False,
            'type_show': 'date',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 115,
            'temp_show': False,
        },
        'field_85': {
            'value': 'field_85',
            'dynamic_show': 'none',
            'name': "Spouse's Medicare Part B Plan",
            'show': False,
            'type_show': 'date',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 116,
            'temp_show': False,
        },
        'field_29': {
            'value': 'field_29',
            'dynamic_show': 'none',
            'name': "Spouse's Phone Number",
            'show': False,
            'type_show': 'phone',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 117,
            'temp_show': False,
        },
        'field_37': {
            'value': 'field_37',
            'dynamic_show': 'none',
            'name': "Spouse's Plan",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 118,
            'temp_show': False,
        },
        'field_44': {
            'value': 'field_44',
            'dynamic_show': 'none',
            'name': "Spouse's Postal Code",
            'show': False,
            'type_show': 'integer',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 120,
            'temp_show': False,
        },
        'field_94': {
            'value': 'field_94',
            'dynamic_show': 'decimal_2',
            'name': "Spouse's Premium",
            'show': False,
            'type_show': 'number',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 112,
            'temp_show': False,
        },
        'field_34': {
            'value': 'field_34',
            'dynamic_show': 'none',
            'name': "Spouse's Product",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 121,
            'temp_show': False,
        },
        'field_36': {
            'value': 'field_36',
            'dynamic_show': 'none',
            'name': "Spouse's Product App ID",
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 122,
            'temp_show': False,
        },
        'field_35': {
            'value': 'field_35',
            'dynamic_show': 'none',
            'name': "Spouse's Product Carrier",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 123,
            'temp_show': False,
        },
        'field_32': {
            'value': 'field_32',
            'dynamic_show': 'none',
            'name': "Spouse's State",
            'show': False,
            'type_show': 'state',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 124,
            'temp_show': False,
        },
        'field_33': {
            'value': 'field_33',
            'dynamic_show': 'none',
            'name': "Spouse's Type of SALE",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 125,
            'temp_show': False,
        },
        'field_5': {
            'value': 'field_5',
            'dynamic_show': 'none',
            'name': "Spouse's Type of UPSELL",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 126,
            'temp_show': False,
        },
        'field_38': {
            'value': 'field_38',
            'dynamic_show': 'none',
            'name': "Spouse's Upsell",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 127,
            'temp_show': False,
        },
        'field_40': {
            'value': 'field_40',
            'dynamic_show': 'none',
            'name': "Spouse's Upsell #2",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 128,
            'temp_show': False,
        },
        'field_203': {
            'value': 'field_203',
            'dynamic_show': 'none',
            'name': "Spouse's Upsell #2 App ID",
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 129,
            'temp_show': False,
        },
        'field_202': {
            'value': 'field_202',
            'dynamic_show': 'none',
            'name': "Spouse's Upsell #2 Carrier",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 130,
            'temp_show': False,
        },
        'field_201': {
            'value': 'field_201',
            'dynamic_show': 'none',
            'name': "Spouse's Upsell App ID",
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 131,
            'temp_show': False,
        },
        'field_39': {
            'value': 'field_39',
            'dynamic_show': 'none',
            'name': "Spouse's Upsell Carrier",
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 132,
            'temp_show': False,
        },
        'field_205': {
            'value': 'field_205',
            'dynamic_show': 'none',
            'name': 'Spouse Cell Phone',
            'show': False,
            'type_show': 'phone',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 133,
            'temp_show': False,
        },
        'field_204': {
            'value': 'field_204',
            'dynamic_show': 'none',
            'name': 'Spouse Email',
            'show': False,
            'type_show': 'email',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 134,
            'temp_show': False,
        },
        'field_27': {
            'value': 'field_27',
            'dynamic_show': 'none',
            'name': 'Spouse First Name',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 135,
            'temp_show': False,
        },
        'field_28': {
            'value': 'field_28',
            'dynamic_show': 'none',
            'name': 'Spouse Last Name',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 136,
            'temp_show': False,
        },
        'field_1': {
            'value': 'field_1',
            'dynamic_show': 'none',
            'name': 'Spouse Life Product',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 144,
            'temp_show': False,
        },
        'state': {
            'value': 'state',
            'dynamic_show': 'none',
            'name': 'State',
            'show': True,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead',
            'order': 34,
            'temp_show': True,
        },
        'field_6': {
            'value': 'field_6',
            'dynamic_show': 'none',
            'name': 'TCPA',
            'show': False,
            'type_show': 'long_select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 137,
            'temp_show': False,
        },
        'field_207': {
            'value': 'field_207',
            'dynamic_show': 'none',
            'name': 'transfer',
            'show': True,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 138,
            'temp_show': True,
        },
        'field_213': {
            'value': 'field_213',
            'dynamic_show': 'none',
            'name': 'transfer_agent',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 99,
            'temp_show': False,
        },
        'field_208': {
            'value': 'field_208',
            'dynamic_show': 'none',
            'name': 'Transfer Sale',
            'show': True,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 139,
            'temp_show': True,
        },
        'field_10': {
            'value': 'field_10',
            'dynamic_show': 'none',
            'name': 'Type of SALE',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 140,
            'temp_show': False,
        },
        'field_9': {
            'value': 'field_9',
            'dynamic_show': 'none',
            'name': 'Type of UPSELL',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 141,
            'temp_show': False,
        },
        'field_21': {
            'value': 'field_21',
            'dynamic_show': 'none',
            'name': 'Upsell',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 142,
            'temp_show': False,
        },
        'field_22': {
            'value': 'field_22',
            'dynamic_show': 'none',
            'name': 'Upsell #2',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 143,
            'temp_show': False,
        },
        'field_25': {
            'value': 'field_25',
            'dynamic_show': 'none',
            'name': 'Upsell #2 Application ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 145,
            'temp_show': False,
        },
        'field_26': {
            'value': 'field_26',
            'dynamic_show': 'none',
            'name': 'Upsell #2 Carrier',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 146,
            'temp_show': False,
        },
        'field_24': {
            'value': 'field_24',
            'dynamic_show': 'none',
            'name': 'Upsell Application ID',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 147,
            'temp_show': False,
        },
        'field_23': {
            'value': 'field_23',
            'dynamic_show': 'none',
            'name': 'Upsell Carrier',
            'show': False,
            'type_show': 'select',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 148,
            'temp_show': False,
        },
        'vendor_lead_code': {
            'value': 'vendor_lead_code',
            'dynamic_show': 'none',
            'name': 'Vendor Code',
            'show': False,
            'section': 'Contact',
            'type_show': 'string',
            'table': 'lead',
            'order': 149,
            'temp_show': False,
        },
        'field_8': {
            'value': 'field_8',
            'dynamic_show': 'none',
            'name': 'Vendor Lead Code',
            'show': True,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 150,
            'temp_show': True,
        },
        'field_211': {
            'value': 'field_211',
            'dynamic_show': 'none',
            'name': 'vertical',
            'show': False,
            'type_show': 'text',
            'section': 'Contact',
            'table': 'lead_info',
            'order': 152,
            'temp_show': False,
        },
        'alt_phone_2': {
            'value': 'alt_phone_2',
            'dynamic_show': 'none',
            'name': 'Work Phone',
            'show': False,
            'type_show': 'phone',
            'section': 'Contact',
            'table': 'lead',
            'order': 151,
            'temp_show': False,
        },
    },
}

response = requests.post('https://admin-dt.convoso.com/log/search', cookies=cookies, headers=headers, json=json_data)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"export":"no","type":"main","selectOptions":[{"name":"status","operator":"IN","value":["SALE","SSALE"],"type":"2"}],"orderOptions":{"name":"id","value":"DESC"},"page":0,"limit":20,"start_date":"2023-04-18 12:00 AM","end_date":"2023-04-18 11:55 PM","columns_list":{"id":{"value":"id","dynamic_show":"none","name":"Call Log ID","type_show":"number","show":true,"section":"Calls","table":"log","order":2,"temp_show":true},"lead_id":{"value":"lead_id","dynamic_show":"lead_id","name":"Lead ID","type_show":"number","show":true,"section":"Calls","table":"log","order":1,"temp_show":true},"log_phone_number":{"value":"log_phone_number","dynamic_show":"none","name":"Number Dialed","type_show":"number","show":true,"section":"Calls","table":"log","order":7,"temp_show":true},"caller_id_displayed":{"value":"caller_id_displayed","dynamic_show":"caller_id_displayed","name":"Caller ID","type_show":"number","show":true,"section":"Calls","table":"log","order":9,"temp_show":true},"status_name":{"value":"status_name","dynamic_show":"none","name":"Status Name","type_show":"string","show":true,"section":"Calls","table":"log","order":56,"temp_show":true},"call_date":{"value":"call_date","dynamic_show":"call_date","name":"Time Stamp (PST)","type_show":"string","show":true,"section":"Time","table":"log","order":10,"temp_show":true},"user_name":{"value":"user_name","dynamic_show":"user_name","name":"Agent Name","type_show":"string","show":true,"section":"Agent","table":"log","order":11,"temp_show":true},"length_in_sec":{"value":"length_in_sec","dynamic_show":"none","name":"Talk Time","type_show":"number","show":true,"section":"Call Statistics","table":"log","order":12,"temp_show":true},"bill_time":{"value":"bill_time","dynamic_show":"none","name":"Bill Time","type_show":"string","show":true,"section":"Call Statistics","table":"log","order":13,"temp_show":true},"queue_seconds":{"value":"queue_seconds","dynamic_show":"none","name":"Queue Wait Time","type_show":"string","show":false,"section":"Call Statistics","table":"log","order":14,"temp_show":false},"cost":{"value":"cost","dynamic_show":"decimal_5","name":"Cost","type_show":"number","show":false,"section":"Call Statistics","table":"log","order":15,"temp_show":false},"call_type":{"value":"call_type","dynamic_show":"call_type","name":"Call Type","type_show":"string","show":true,"section":"Calls","table":"log","order":16,"temp_show":true},"term_reason":{"value":"term_reason","dynamic_show":"term_reason","name":"Termination Reason","type_show":"string","show":true,"section":"Calls","table":"log","order":17,"temp_show":true},"out_called_count":{"value":"out_called_count","dynamic_show":"none","name":"Outbound Called Count","type_show":"number","show":true,"section":"Call Statistics","table":"log","order":18,"temp_show":true},"campaign_name":{"value":"campaign_name","dynamic_show":"campaign_name","name":"Campaign Name","type_show":"string","show":true,"section":"Calls","table":"log","order":3,"temp_show":true},"directory_name":{"value":"directory_name","dynamic_show":"directory_name","name":"List Name","type_show":"string","show":false,"section":"Calls","table":"log","order":19,"temp_show":false},"queue_name":{"value":"queue_name","dynamic_show":"none","name":"Queue Name","type_show":"string","show":true,"section":"Calls","table":"log","order":20,"temp_show":true},"recording":{"value":"recording","dynamic_show":"recording","name":"Recordings","type_show":"string","show":false,"section":"Calls","table":"log","order":21,"temp_show":false},"agent_comment":{"value":"agent_comment","dynamic_show":"none","name":"Comment","type_show":"string","show":true,"section":"Agent","table":"log","order":22,"temp_show":true},"audio_score":{"value":"audio_score","dynamic_show":"audio_score","name":"Audio Quality","type_show":"string","show":false,"section":"Call Statistics","table":"log","order":23,"temp_show":false},"revenue":{"value":"revenue","dynamic_show":"none","name":"Revenue","type_show":"number","show":false,"section":"Call Statistics","table":"log","order":30,"temp_show":false},"returns":{"value":"returns","dynamic_show":"none","name":"Returned","type_show":"string","show":false,"section":"Call Statistics","table":"log","order":31,"temp_show":false},"agent_email":{"value":"agent_email","dynamic_show":"none","name":"Agent Email","type_show":"string","show":false,"section":"Agent","table":"user","order":24,"temp_show":false},"extension":{"value":"extension","dynamic_show":"none","name":"Agent Extension","type_show":"number","show":false,"section":"Agent","table":"phone","order":25,"temp_show":false},"agent_first_name":{"value":"agent_first_name","dynamic_show":"none","name":"Agent First Name","type_show":"string","show":false,"section":"Agent","table":"user","order":27,"temp_show":false},"user_id":{"value":"user_id","dynamic_show":"none","name":"Agent ID","type_show":"number","show":false,"section":"Agent","table":"log","order":29,"temp_show":false},"agent_last_name":{"value":"agent_last_name","dynamic_show":"none","name":"Agent Last Name","type_show":"string","show":false,"section":"Agent","table":"user","order":33,"temp_show":false},"called_since_last_reset":{"value":"called_since_last_reset","dynamic_show":"none","name":"Called Since Last Reset","type_show":"string","show":false,"section":"Call Statistics","table":"lead","order":36,"temp_show":false},"dispo_sec":{"value":"dispo_sec","dynamic_show":"none","name":"Wrap-up Time","type_show":"number","show":false,"section":"Call Statistics","table":"agent_log","order":37,"temp_show":false},"date_and_hour":{"value":"date_and_hour","dynamic_show":"none","name":"Date and Hour","type_show":"string","show":true,"section":"Time","table":"log","order":38,"temp_show":true},"day_of_month":{"value":"day_of_month","dynamic_show":"none","name":"Day of Month","type_show":"number","show":false,"section":"Time","table":"log","order":39,"temp_show":false},"day_of_week":{"value":"day_of_week","dynamic_show":"none","name":"Day of Week","type_show":"string","show":false,"section":"Time","table":"log","order":40,"temp_show":false},"end_epoch":{"value":"end_epoch","dynamic_show":"none","name":"End Epoch","type_show":"number","show":false,"section":"Time","table":"log","order":41,"temp_show":false},"hour":{"value":"hour","dynamic_show":"none","name":"Hour","type_show":"number","show":false,"section":"Time","table":"log","order":42,"temp_show":false},"month":{"value":"month","dynamic_show":"none","name":"Month","type_show":"string","show":false,"section":"Time","table":"log","order":43,"temp_show":false},"start_epoch":{"value":"start_epoch","dynamic_show":"none","name":"Start Epoch","type_show":"number","show":false,"section":"Time","table":"log","order":44,"temp_show":false},"call_log_time":{"value":"call_log_time","dynamic_show":"none","name":"Time","type_show":"number","show":false,"section":"Time","table":"log","order":45,"temp_show":false},"year":{"value":"year","dynamic_show":"none","name":"Year","type_show":"number","show":false,"section":"Time","table":"log","order":46,"temp_show":false},"alt_dial":{"value":"alt_dial","dynamic_show":"none","name":"Alternate Number to Dial","type_show":"number","show":false,"section":"Calls","table":"log","order":47,"temp_show":false},"campaign_id":{"value":"campaign_id","dynamic_show":"none","name":"Campaign ID","type_show":"number","show":false,"section":"Calls","table":"log","order":48,"temp_show":false},"campaign_type":{"value":"campaign_type","dynamic_show":"none","name":"Campaign Type","type_show":"string","show":false,"section":"Calls","table":"log","order":49,"temp_show":false},"queue_id":{"value":"queue_id","dynamic_show":"queue_id","name":"Queue ID","type_show":"number","show":false,"section":"Calls","table":"log","order":52,"temp_show":false},"call_id":{"value":"call_id","dynamic_show":"none","name":"Session ID","type_show":"number","show":false,"section":"Calls","table":"log","order":53,"temp_show":false},"status":{"value":"status","dynamic_show":"status","name":"Status","type_show":"string","show":false,"section":"Calls","table":"log","order":54,"temp_show":false},"originating_agent_id":{"value":"originating_agent_id","dynamic_show":"none","name":"Originating Agent ID","type_show":"number","show":false,"section":"Agent","table":"log","order":50,"temp_show":false},"originating_agent_name":{"value":"originating_agent_name","dynamic_show":"originating_agent_name","name":"Originating Agent Name","type_show":"string","show":true,"section":"Agent","table":"log","order":51,"temp_show":true},"owner_id":{"value":"owner_id","dynamic_show":"owner_id","name":"Lead Owner","show":false,"temp_show":false,"section":"Agent","order":81},"last_modified_by":{"value":"last_modified_by","dynamic_show":"last_modified_by","name":"Last Modified By","show":false,"temp_show":false,"section":"Agent","order":80},"created_by":{"value":"created_by","dynamic_show":"created_by","name":"Created By","show":false,"temp_show":false,"section":"Agent","order":55},"address1":{"value":"address1","dynamic_show":"none","name":"Address 1","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":28,"temp_show":false},"address2":{"value":"address2","dynamic_show":"none","name":"Address 2","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":62,"temp_show":false},"field_217":{"value":"field_217","dynamic_show":"none","name":"AgentX (UHC Only)","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":59,"temp_show":false},"field_41":{"value":"field_41","dynamic_show":"none","name":"Annual Premium ($)","show":false,"type_show":"integer","section":"Contact","table":"lead_info","order":60,"temp_show":false},"field_210":{"value":"field_210","dynamic_show":"none","name":"blueink_token","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":61,"temp_show":false},"carrier_name":{"value":"carrier_name","dynamic_show":"none","name":"Carrier Name","show":false,"section":"Contact","type_show":"string","table":"lead","order":63,"temp_show":false},"carrier_type":{"value":"carrier_type","dynamic_show":"none","name":"Carrier Type","show":false,"section":"Contact","type_show":"string","table":"lead","order":64,"temp_show":false},"alt_phone_1":{"value":"alt_phone_1","dynamic_show":"none","name":"Cell Phone","show":false,"type_show":"phone","section":"Contact","table":"lead","order":65,"temp_show":false},"city":{"value":"city","dynamic_show":"none","name":"City","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":32,"temp_show":false},"field_95":{"value":"field_95","dynamic_show":"decimal_2","name":"Cost","show":false,"type_show":"number","section":"Contact","table":"lead_info","order":67,"temp_show":false},"country":{"value":"country","dynamic_show":"none","name":"Country","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":68,"temp_show":false},"phone_code":{"value":"phone_code","dynamic_show":"none","name":"Country Code","show":false,"type_show":"select","section":"Contact","table":"lead","order":69,"temp_show":false},"created_at":{"value":"created_at","dynamic_show":"none","name":"Created At (Time)","show":true,"section":"Contact","type_show":"string","table":"lead","order":57,"temp_show":true},"date_of_birth":{"value":"date_of_birth","dynamic_show":"none","name":"Date Of Birth","show":false,"type_show":"date","section":"Contact","table":"lead_info","order":70,"temp_show":false},"field_214":{"value":"field_214","dynamic_show":"none","name":"DialedNumber Name","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":72,"temp_show":false},"email":{"value":"email","dynamic_show":"none","name":"Email","show":false,"type_show":"email","section":"Contact","table":"lead","order":8,"temp_show":false},"final_reached_at":{"value":"final_reached_at","dynamic_show":"none","name":"Final Reached At","show":false,"section":"Contact","type_show":"string","table":"lead","order":71,"temp_show":false},"first_name":{"value":"first_name","dynamic_show":"none","name":"First Name","show":true,"section":"Contact","table":"lead","order":4,"temp_show":true},"field_43":{"value":"field_43","dynamic_show":"none","name":"FL Call Counter","show":false,"type_show":"integer","section":"Contact","table":"lead_info","order":73,"temp_show":false},"gender":{"value":"gender","dynamic_show":"none","name":"Gender","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":74,"temp_show":false},"gmt_offset_now":{"value":"gmt_offset_now","dynamic_show":"decimal_2","name":"GMT Offset Now","show":false,"section":"Contact","type_show":"number","table":"lead","order":26,"temp_show":false},"field_216":{"value":"field_216","dynamic_show":"none","name":"HRA","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":76,"temp_show":false},"field_206":{"value":"field_206","dynamic_show":"none","name":"Jornaya Hidden Field","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":75,"temp_show":false},"last_local_call_time":{"value":"last_local_call_time","dynamic_show":"none","name":"Last Called (PST)","show":false,"section":"Contact","type_show":"string","table":"lead","order":77,"temp_show":false},"last_name":{"value":"last_name","dynamic_show":"none","name":"Last Name","show":true,"section":"Contact","table":"lead","order":5,"temp_show":true},"last_reached_at":{"value":"last_reached_at","dynamic_show":"none","name":"Last Reached At","show":false,"section":"Contact","type_show":"string","table":"lead","order":78,"temp_show":false},"last_viewed_date":{"value":"last_viewed_date","dynamic_show":"none","name":"Last Viewed","show":false,"section":"Contact","type_show":"string","table":"lead","order":79,"temp_show":false},"field_12":{"value":"field_12","dynamic_show":"none","name":"LeadsPedia Affiliate ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":83,"temp_show":false},"field_13":{"value":"field_13","dynamic_show":"none","name":"LeadsPedia Campaign ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":84,"temp_show":false},"field_11":{"value":"field_11","dynamic_show":"none","name":"LeadsPedia Lead ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":85,"temp_show":false},"field_14":{"value":"field_14","dynamic_show":"none","name":"LeadsPedia Offer ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":87,"temp_show":false},"field_15":{"value":"field_15","dynamic_show":"none","name":"LeadsPedia Vertical ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":88,"temp_show":false},"field_2":{"value":"field_2","dynamic_show":"none","name":"Life Product","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":92,"temp_show":false},"field_215":{"value":"field_215","dynamic_show":"none","name":"Life Product Application ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":86,"temp_show":false},"list_id":{"value":"list_id","dynamic_show":"none","name":"List","show":true,"type_show":"lookup","section":"Contact","table":"lead","order":89,"temp_show":true},"field_209":{"value":"field_209","dynamic_show":"none","name":"lp_campaign_key","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":90,"temp_show":false},"field_218":{"value":"field_218","dynamic_show":"none","name":"Medicaid Number","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":82,"temp_show":false},"field_4":{"value":"field_4","dynamic_show":"none","name":"Medicare Number","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":91,"temp_show":false},"field_81":{"value":"field_81","dynamic_show":"none","name":"Medicare Part A Date","show":false,"type_show":"date","section":"Contact","table":"lead_info","order":93,"temp_show":false},"field_82":{"value":"field_82","dynamic_show":"none","name":"Medicare Part B Date","show":false,"type_show":"date","section":"Contact","table":"lead_info","order":94,"temp_show":false},"modified_at":{"value":"modified_at","dynamic_show":"none","name":"Last Modify","show":false,"section":"Contact","type_show":"string","table":"lead","order":58,"temp_show":false},"field_101":{"value":"field_101","dynamic_show":"none","name":"Notes","show":false,"type_show":"textarea_long","section":"Contact","table":"lead_info","order":95,"temp_show":false},"field_20":{"value":"field_20","dynamic_show":"none","name":"Plan","show":true,"type_show":"select","section":"Contact","table":"lead_info","order":96,"temp_show":true},"postal_code":{"value":"postal_code","dynamic_show":"none","name":"Postal Code","show":true,"type_show":"text","section":"Contact","table":"lead","order":35,"temp_show":true},"field_93":{"value":"field_93","dynamic_show":"decimal_2","name":"Premium","show":true,"type_show":"number","section":"Contact","table":"lead_info","order":66,"temp_show":true},"phone_number":{"value":"phone_number","dynamic_show":"none","name":"Primary Phone","show":true,"type_show":"phone","section":"Contact","table":"lead","order":6,"temp_show":true},"field_17":{"value":"field_17","dynamic_show":"none","name":"Product","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":97,"temp_show":false},"field_3":{"value":"field_3","dynamic_show":"none","name":"Product Application ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":114,"temp_show":false},"field_19":{"value":"field_19","dynamic_show":"none","name":"Product Application ID (OLD)","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":98,"temp_show":false},"field_18":{"value":"field_18","dynamic_show":"none","name":"Product Carrier","show":true,"type_show":"select","section":"Contact","table":"lead_info","order":100,"temp_show":true},"province":{"value":"province","dynamic_show":"none","name":"Province","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":102,"temp_show":false},"field_301":{"value":"field_301","dynamic_show":"none","name":"ringba_conversion","show":false,"type_show":"integer","section":"Contact","table":"lead_info","order":101,"temp_show":false},"field_212":{"value":"field_212","dynamic_show":"none","name":"Ringba Call ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":108,"temp_show":false},"field_83":{"value":"field_83","dynamic_show":"none","name":"Sale Date","show":false,"type_show":"datetime","section":"Contact","table":"lead_info","order":103,"temp_show":false},"field_16":{"value":"field_16","dynamic_show":"none","name":"Sale Status","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":104,"temp_show":false},"security_phrase":{"value":"security_phrase","dynamic_show":"none","name":"Security Phrase","show":false,"section":"Contact","type_show":"string","table":"lead","order":105,"temp_show":false},"source_id":{"value":"source_id","dynamic_show":"none","name":"Source Id","show":false,"section":"Contact","type_show":"number","table":"lead","order":106,"temp_show":false},"source_name":{"value":"source_name","dynamic_show":"none","name":"Source Name","show":true,"section":"Contact","type_show":"string","table":"lead","order":107,"temp_show":true},"field_7":{"value":"field_7","dynamic_show":"none","name":"Source Lead List","show":true,"type_show":"text","section":"Contact","table":"lead_info","order":109,"temp_show":true},"field_30":{"value":"field_30","dynamic_show":"none","name":"Spouse\'s Address","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":110,"temp_show":false},"field_31":{"value":"field_31","dynamic_show":"none","name":"Spouse\'s City","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":111,"temp_show":false},"field_401":{"value":"field_401","dynamic_show":"none","name":"Spouse\'s Date of Birth","show":false,"type_show":"date","section":"Contact","table":"lead_info","order":113,"temp_show":false},"field_42":{"value":"field_42","dynamic_show":"none","name":"Spouse\'s  Life Premium","show":false,"type_show":"integer","section":"Contact","table":"lead_info","order":119,"temp_show":false},"field_84":{"value":"field_84","dynamic_show":"none","name":"Spouse\'s Medicare Part A Plan","show":false,"type_show":"date","section":"Contact","table":"lead_info","order":115,"temp_show":false},"field_85":{"value":"field_85","dynamic_show":"none","name":"Spouse\'s Medicare Part B Plan","show":false,"type_show":"date","section":"Contact","table":"lead_info","order":116,"temp_show":false},"field_29":{"value":"field_29","dynamic_show":"none","name":"Spouse\'s Phone Number","show":false,"type_show":"phone","section":"Contact","table":"lead_info","order":117,"temp_show":false},"field_37":{"value":"field_37","dynamic_show":"none","name":"Spouse\'s Plan","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":118,"temp_show":false},"field_44":{"value":"field_44","dynamic_show":"none","name":"Spouse\'s Postal Code","show":false,"type_show":"integer","section":"Contact","table":"lead_info","order":120,"temp_show":false},"field_94":{"value":"field_94","dynamic_show":"decimal_2","name":"Spouse\'s Premium","show":false,"type_show":"number","section":"Contact","table":"lead_info","order":112,"temp_show":false},"field_34":{"value":"field_34","dynamic_show":"none","name":"Spouse\'s Product","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":121,"temp_show":false},"field_36":{"value":"field_36","dynamic_show":"none","name":"Spouse\'s Product App ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":122,"temp_show":false},"field_35":{"value":"field_35","dynamic_show":"none","name":"Spouse\'s Product Carrier","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":123,"temp_show":false},"field_32":{"value":"field_32","dynamic_show":"none","name":"Spouse\'s State","show":false,"type_show":"state","section":"Contact","table":"lead_info","order":124,"temp_show":false},"field_33":{"value":"field_33","dynamic_show":"none","name":"Spouse\'s Type of SALE","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":125,"temp_show":false},"field_5":{"value":"field_5","dynamic_show":"none","name":"Spouse\'s Type of UPSELL","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":126,"temp_show":false},"field_38":{"value":"field_38","dynamic_show":"none","name":"Spouse\'s Upsell","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":127,"temp_show":false},"field_40":{"value":"field_40","dynamic_show":"none","name":"Spouse\'s Upsell #2","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":128,"temp_show":false},"field_203":{"value":"field_203","dynamic_show":"none","name":"Spouse\'s Upsell #2 App ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":129,"temp_show":false},"field_202":{"value":"field_202","dynamic_show":"none","name":"Spouse\'s Upsell #2 Carrier","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":130,"temp_show":false},"field_201":{"value":"field_201","dynamic_show":"none","name":"Spouse\'s Upsell App ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":131,"temp_show":false},"field_39":{"value":"field_39","dynamic_show":"none","name":"Spouse\'s Upsell Carrier","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":132,"temp_show":false},"field_205":{"value":"field_205","dynamic_show":"none","name":"Spouse Cell Phone","show":false,"type_show":"phone","section":"Contact","table":"lead_info","order":133,"temp_show":false},"field_204":{"value":"field_204","dynamic_show":"none","name":"Spouse Email","show":false,"type_show":"email","section":"Contact","table":"lead_info","order":134,"temp_show":false},"field_27":{"value":"field_27","dynamic_show":"none","name":"Spouse First Name","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":135,"temp_show":false},"field_28":{"value":"field_28","dynamic_show":"none","name":"Spouse Last Name","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":136,"temp_show":false},"field_1":{"value":"field_1","dynamic_show":"none","name":"Spouse Life Product","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":144,"temp_show":false},"state":{"value":"state","dynamic_show":"none","name":"State","show":true,"type_show":"select","section":"Contact","table":"lead","order":34,"temp_show":true},"field_6":{"value":"field_6","dynamic_show":"none","name":"TCPA","show":false,"type_show":"long_select","section":"Contact","table":"lead_info","order":137,"temp_show":false},"field_207":{"value":"field_207","dynamic_show":"none","name":"transfer","show":true,"type_show":"select","section":"Contact","table":"lead_info","order":138,"temp_show":true},"field_213":{"value":"field_213","dynamic_show":"none","name":"transfer_agent","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":99,"temp_show":false},"field_208":{"value":"field_208","dynamic_show":"none","name":"Transfer Sale","show":true,"type_show":"select","section":"Contact","table":"lead_info","order":139,"temp_show":true},"field_10":{"value":"field_10","dynamic_show":"none","name":"Type of SALE","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":140,"temp_show":false},"field_9":{"value":"field_9","dynamic_show":"none","name":"Type of UPSELL","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":141,"temp_show":false},"field_21":{"value":"field_21","dynamic_show":"none","name":"Upsell","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":142,"temp_show":false},"field_22":{"value":"field_22","dynamic_show":"none","name":"Upsell #2","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":143,"temp_show":false},"field_25":{"value":"field_25","dynamic_show":"none","name":"Upsell #2 Application ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":145,"temp_show":false},"field_26":{"value":"field_26","dynamic_show":"none","name":"Upsell #2 Carrier","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":146,"temp_show":false},"field_24":{"value":"field_24","dynamic_show":"none","name":"Upsell Application ID","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":147,"temp_show":false},"field_23":{"value":"field_23","dynamic_show":"none","name":"Upsell Carrier","show":false,"type_show":"select","section":"Contact","table":"lead_info","order":148,"temp_show":false},"vendor_lead_code":{"value":"vendor_lead_code","dynamic_show":"none","name":"Vendor Code","show":false,"section":"Contact","type_show":"string","table":"lead","order":149,"temp_show":false},"field_8":{"value":"field_8","dynamic_show":"none","name":"Vendor Lead Code","show":true,"type_show":"text","section":"Contact","table":"lead_info","order":150,"temp_show":true},"field_211":{"value":"field_211","dynamic_show":"none","name":"vertical","show":false,"type_show":"text","section":"Contact","table":"lead_info","order":152,"temp_show":false},"alt_phone_2":{"value":"alt_phone_2","dynamic_show":"none","name":"Work Phone","show":false,"type_show":"phone","section":"Contact","table":"lead","order":151,"temp_show":false}}}'
#response = requests.post('https://admin-dt.convoso.com/log/search', cookies=cookies, headers=headers, data=data)

# %%
r = response.json()['data']['results']

# %%
sales = pd.json_normalize(r)

# %%
# Step: Drop columns
sales = sales.drop(columns=['audio_score', 'start_epoch', 'end_epoch', 'user_id', 'comments', 'agent_comment', 'processed', 'alt_dial', 'xfer_call_id', 'agent_only', 'caller_id_tracking', 'originated_log_id', 'extra_field_one', 'extra_field_two', 'originating_agent_id', 'owner_id', 'remote_id', 'called_since_last_reset', 'alt_phone_2', 'alt_phone_1', 'locale_gmt', 'security_phrase', 'last_viewed', 'deleted_at', 'lead_json_object', 'script_json_data', 'last_viewed_date', 'user_uid', 'owner_uid', 'owner_name', 'last_modified_by_uid', 'last_modified_by_name', 'created_by_user_uid', 'created_by_user_name', 'source_uid', 'campaign_uid', 'recording', 'mini_tcpa_blocked', 'returns', 'queue_uid'])

# Step: Drop columns
sales = sales.drop(columns=['unique_id', 'call_id', 'vendor_code', 'source_id', 'lead_list_id', 'object_type', 'created_by', 'next_allow_contact_time', 'directory_uid', 'campaign_type', 'field_93', 'revenue'])

# Step: Rename multiple columns
sales = sales.rename(columns={'field_18': 'product_carrier', 'field_20': 'carrier_plan'})

# Step: Drop columns
sales = sales.drop(columns=['field_8', 'field_7', 'field_208'])

# Step: Change data type of call_date to Datetime
sales['call_date'] = pd.to_datetime(sales['call_date'], infer_datetime_format=True)

# Step: Change data type of created_at to Datetime
sales['created_at'] = pd.to_datetime(sales['created_at'], infer_datetime_format=True)

# Step: Drop columns
sales = sales.drop(columns=['last_reached_at', 'last_modified_by'])

# Step: Change data type of date_and_hour to Datetime
sales['date_and_hour'] = pd.to_datetime(sales['date_and_hour'], infer_datetime_format=True)

# Step: Change data type of modified_at to Datetime
sales['modified_at'] = pd.to_datetime(sales['modified_at'], infer_datetime_format=True)

# Step: Change data type of final_reached_at to Datetime
sales['final_reached_at'] = pd.to_datetime(sales['final_reached_at'], infer_datetime_format=True)

# Step: Change data type of last_local_call_time to Datetime
sales['last_local_call_time'] = pd.to_datetime(sales['last_local_call_time'], infer_datetime_format=True)

# Step: Change data type of call_log_date to Datetime
sales['call_log_date'] = pd.to_datetime(sales['call_log_date'], infer_datetime_format=True)

# Step: Drop columns
sales = sales.drop(columns=['field_207'])

# Step: Change data type of ['id', 'lead_id', 'campaign_id', 'phone_code', 'phone_number', 'term_reason', 'queue_seconds', 'call_type', 'queue_id', 'first_name', 'last_name', 'email', 'postal_code', 'state', 'status', 'status_name', 'carrier_name', 'carrier_type', 'carrier_plan', 'product_carrier'] to String/Text
for column_name in ['id', 'lead_id', 'campaign_id', 'phone_code', 'phone_number', 'term_reason', 'queue_seconds', 'call_type', 'queue_id', 'first_name', 'last_name', 'email', 'postal_code', 'state', 'status', 'status_name', 'carrier_name', 'carrier_type', 'carrier_plan', 'product_carrier']:
    sales[column_name] = sales[column_name].astype('string')

# Step: Change data type of length_in_sec to Integer
sales['length_in_sec'] = pd.to_numeric(sales['length_in_sec'], downcast='integer', errors='coerce')

# Step: Change data type of queue_position to Integer
sales['queue_position'] = pd.to_numeric(sales['queue_position'], downcast='integer', errors='coerce')

# Step: Change data type of call_duration to Float
sales['call_duration'] = pd.to_numeric(sales['call_duration'], downcast='float', errors='coerce')

# Step: Change data type of called_count_inbound to Integer
sales['called_count_inbound'] = pd.to_numeric(sales['called_count_inbound'], downcast='integer', errors='coerce')

# Step: Change data type of ['called_count', 'did_id', 'cost', 'last_called', 'out_called_count', 'call_log_time', 'log_phone_number', 'vendor_lead_code', 'gmt_offset_now', 'year', 'month', 'hour', 'day_of_month', 'day_of_week', 'real_lead_id', 'directory_name', 'source_name', 'campaign_name', 'bill_time', 'inbound_number', 'queue_name'] to String/Text
for column_name in sales.select_dtypes(['object']).columns:
    sales[column_name] = sales[column_name].astype('string')

# Step: Change data type of out_called_count to Integer
sales['out_called_count'] = pd.to_numeric(sales['out_called_count'], downcast='integer', errors='coerce')

# Step: Create new column 'phone_key' from formula 'phone_code + phone_number'
sales['phone_key'] = sales['phone_code'] + sales['phone_number']

# Step: Rename multiple columns
sales = sales.rename(columns={'field_4': 'Medicare Number', 'field_3': 'Product_Application_id'})

# %%
def select_last_six_chars(df, column_name):
    """
    Returns a new dataframe with a new column containing the last 6 characters of the input column.
    """
    new_col_name = column_name + '_last_six_chars'
    df[new_col_name] = df[column_name].str[-6:]
    return df

# %%
import pandas as pd; import numpy as np
# Step: Create new column 'DupCheckKey' from formula 'phone_key + lead_id'
sales['DupCheckKey'] = sales['phone_key'] + sales['lead_id']

sales
# Out:
#          id lead_id list_id campaign_id           call_date  length_in_sec  \
# 0   2836392  605984    3116         173 2023-06-07 16:50:29             60
# 1   2836260  606009    2935         178 2023-06-07 15:06:38           1804
# 2   2836168  572401     625         173 2023-06-07 14:53:24           3830
# 3   2836114  605984    3116         173 2023-06-07 14:48:55           7204
# 4   2835954  606024     657         173 2023-06-07 14:37:24           1390
# 5   2835315  606009    2990         178 2023-06-07 13:49:30           4401
# 6   2834978  605921    3116         173 2023-06-07 13:26:40           6655
# 7   2834969  605964    3116         173 2023-06-07 13:26:00           3434
# 8   2834878  605940    2907         178 2023-06-07 13:18:19           3840
# 9   2834522  605882    2990         173 2023-06-07 12:44:28           7131
# 10  2834365  605841    2907         173 2023-06-07 12:25:55           4076
# ...

# %%
import bamboolib
import pandas as pd; import numpy as np
# Step: Drop columns
sales = sales.drop(columns=['originating_agent_uid', 'originating_agent_name'])

# %%
# Step: Drop columns
sales = sales.drop(columns=['Medicare Number'])

# %%
sql_str = 'mariadb+pymysql://mike@data.caridamedsupp.com:Rutgers-72@45.79.131.179/Customers'
          
# Create the connection
cnx = create_engine(sql_str)

# %%
sales.to_sql('Expanded Sale Log', con=cnx, if_exists='append', index=False)
# Out:
# 42

# %%
url = "https://api.ringba.com/v2/token"

payload='grant_type=password&username=mike%40carida.com&password=Rutgers-72'
headers = {
  'content-type': 'application/x-www-form-urlencoded; charset=UTF-8'
}

response = requests.request("POST", url, headers=headers, data=payload)

token = response.json()
token = token['access_token']

# %%
url = "https://api.ringba.com/v2/RA0909aa9eddae40c4bb48f7253e6e8742/calllogs/export/csv"

payload = json.dumps({
  "reportEnd": end,
  "reportStart": start,
  "orderByColumns": [
      {
          "column": "callDt",
          "direction": "desc"
      }
  ],
  "valueColumns": [
    {
      "column": "callDt"
    },
    {
      "column": "tag:DialedNumber:Name"
    },
    {
      "column": "campaignName"
    },
    {
      "column": "publisherName"
    },
    {
      "column": "targetName"
    },
    {
      "column": "targetNumber"
    },
    {
      "column": "buyer"
    },
    {
      "column": "inboundPhoneNumber"
    },
    {
      "column": "number"
    },
    {
      "column": "endCallSource"
    },
    {
      "column": "hasConnected"
    },
    {
      "column": "callLengthInSeconds"
    },
    {
      "column": "connectedCallLengthInSeconds"
    },
    {
      "column": "hasPayout"
    },
    {
      "column": "isDuplicate"
    },
    {
      "column": "hasPreviouslyConnected"
    },
    {
      "column": "hasConverted"
    },
    {
      "column": "payoutAmount"
    },
    {
      "column": "tag:InboundNumber:State"
    },
  ]
})
headers = {
  'Authorization': 'Bearer' + ' ' + token,
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

csvid = response.json()['id']

# %%
url = "https://api.ringba.com/v2/RA0909aa9eddae40c4bb48f7253e6e8742/calllogs/export/" + csvid

payload={}
headers = {
  'Authorization': 'Bearer' + ' ' + token
  }

response = requests.request("GET", url, headers=headers, data=payload)

#time.sleep(420)

r = response.json()

# %%
'''poll the API until the file is ready'''
while True:
    response = requests.request("GET", url, headers=headers, data=payload)
    if response.json()['status'] == 'Ready':
        break
    else:
        time.sleep(5)
        continue
# response = requests.request("GET", url, headers=headers, data=payload)
r = response.json()['url']

print('Downloading started')

filename = url.split('/')[-1]

req = requests.get(r)
print('Downloading finished')

'''extract the file to the current directory'''
with zipfile.ZipFile(BytesIO(req.content)) as zip_ref:
    zip_ref.extractall()

# %%
df = pd.concat(map(pd.read_csv, glob.glob('ringba-call-log*.csv')))

# %%
# Step: Change data type of ['Campaign', 'Publisher', 'Target', 'Buyer', 'End Call Source', 'Connected', 'Paid Out', 'Is Duplicate', 'Converted'] to String/Text
for column_name in df.select_dtypes(['object']).columns:
    df[column_name] = df[column_name].astype('string')

# Step: Change data type of Target Number to String/Text
df['Target Number'] = df['Target Number'].astype('string')

# Step: Manipulate strings of 'Target Number' and perform a split on '.'
split_df = df['Target Number'].str.split('\\.', expand=True)
split_df.columns = ['Target Number' + f"_{id_}" for id_ in range(len(split_df.columns))]
df = pd.merge(df, split_df, how="left", left_index=True, right_index=True)

# Step: Drop columns
df = df.drop(columns=['Target Number', 'Target Number_1'])

# Step: Rename column
df = df.rename(columns={'Target Number_0': 'Target Number'})

# Step: Change data type of ['Caller ID', 'Number'] to String/Text
for column_name in ['Caller ID', 'Number']:
    df[column_name] = df[column_name].astype('string')

# Step: Change data type of ['Call Length', 'Connected Call Length', 'Payout'] to Integer
for column_name in df.select_dtypes('float').columns:
    df[column_name] = df[column_name].astype('Int64')

# Step: Drop rows where Payout is missing
df = df.loc[~(df['Payout'].isna())]

df['Call Date'] = pd.to_datetime(df['Call Date'], unit='ms')

df = df.drop(columns=['Converted', 'Campaign'])

ringba = df

# %%
sql_str = 'mariadb+pymysql://mike@data.caridamedsupp.com:Rutgers-72@45.79.131.179/Customers'
          
# Create the connection
cnx = create_engine(sql_str)

# %%
# ringba.to_sql('Ringba Call Log', con=cnx, if_exists='append', index=False)
# Out:
# 290

# %%
'''delete the file that begins with ringba-call-log'''
for file in glob.glob('ringba-call-log*.csv'):
    os.remove(file)

# %%
print("Ringba Call Log Finished")
# Out:
# Ringba Call Log Finished

# %%
# Step: Change data type of Call Date to Datetime
ringba['Call Date'] = pd.to_datetime(ringba['Call Date'], infer_datetime_format=True)

# Step: Change data type of ['Publisher', 'DialedNumber:Name', 'Caller ID', 'Is Duplicate', 'State'] to String/Text
for column_name in ringba.select_dtypes(['object']).columns:
    ringba[column_name] = ringba[column_name].astype('string')

# Step: Left Join with sales where Caller ID=phone_key
ringba_merged = pd.merge(ringba, sales, how='left', left_on=['Caller ID'], right_on=['phone_key'])

# Step: Change data type of last_local_call_time to Datetime
ringba_merged['last_local_call_time'] = pd.to_datetime(ringba_merged['last_local_call_time'], infer_datetime_format=True)

# Step: Change data type of called_count_inbound to Integer
ringba_merged['called_count_inbound'] = ringba_merged['called_count_inbound'].astype('Int64')

# Step: Change data type of called_count to Integer
ringba_merged['called_count'] = ringba_merged['called_count'].astype('Int64')

# Step: Drop columns
ringba_merged = ringba_merged.drop(columns=['state'])

# %%
# Step: Rename column
ringba_merged = ringba_merged.rename(columns={'tag:DialedNumber:Name': 'DialedNumber:Name'})

# Step: Drop columns
ringba_merged = ringba_merged.drop(columns=['Target', 'Target Number'])

# Step: Drop columns
ringba_merged = ringba_merged.drop(columns=['Buyer'])

# Step: Drop columns
ringba_merged = ringba_merged.drop(columns=['Number'])

# Step: Drop columns
ringba_merged = ringba_merged.drop(columns=['End Call Source', 'Connected', 'Connected Call Length'])

# Step: Rename column
ringba_merged = ringba_merged.rename(columns={'tag:InboundNumber:State': 'State'})

# %%
# Step: Change data type of Paid Out to Boolean
ringba_merged['Paid Out'] = ringba_merged['Paid Out'].astype(bool)

# %%
sql_str = 'mariadb+pymysql://mike@data.caridamedsupp.com:Rutgers-72@45.79.131.179/Customers'
          
# Create the connection
cnx = create_engine(sql_str)

# %%
#ringba_merged.to_sql('Ringba Merged', con=cnx, if_exists='append', index=False)
# Out:
# 291
